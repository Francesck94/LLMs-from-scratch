# %% [markdown]
# Calculate and compare the number of parameters that are contained in the feed forward
# module and those that are contained in the multi-head attention module.

# %%
# main.py
import sys
sys.path.insert(0, "../01_main-chapter-code")  # add Folder_2 path to search list

from gpt import FeedForward, MultiHeadAttention

# %%
# gpt setting

# %%
GPT_CONFIG_124M = {
    "vocab_size": 50257,    # Vocabulary size
    "context_length": 1024, # Context length
    "emb_dim": 768,         # Embedding dimension
    "n_heads": 12,          # Number of attention heads
    "n_layers": 12,         # Number of layers
    "drop_rate": 0.1,       # Dropout rate
    "qkv_bias": False       # Query-Key-Value bias
}

# %% [markdown]
# # MultiHeadAttention

# %%
# ?MultiHeadAttention

# %%
d_in = GPT_CONFIG_124M['emb_dim']
d_out = d_in
context_length = GPT_CONFIG_124M['context_length']
dropout = GPT_CONFIG_124M['drop_rate']
num_heads = GPT_CONFIG_124M['n_heads']
qkv_bias= GPT_CONFIG_124M['qkv_bias']

# %%
mha = MultiHeadAttention(d_in=d_in,
                         d_out=d_out,
                         context_length=context_length,
                         dropout=dropout,
                         num_heads=num_heads,
                         qkv_bias=qkv_bias
                        )

# %% [markdown]
# ## FeedForward

# %%
??FeedForward

# %%
ff = FeedForward(GPT_CONFIG_124M)

# %% [markdown]
# # params

# %%
params_mha = sum(p.numel() for p in mha.parameters())
params_mha

# %%
print(f"Total number of parameters of MultiHeadAttention module: {params_mha:,}")

# %%
params_ff = sum(p.numel() for p in ff.parameters())
params_ff

# %%
print(f"Total number of parameters of FeedForward module: {params_ff:,}")
